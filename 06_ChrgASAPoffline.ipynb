# %%
import pandas as pd
import numpy as np
from EvGym import config

# %%
df_sessions = pd.read_csv(f"{config.data_path}/df_elaad_preproc.csv", parse_dates=["starttime_parking", "endtime_parking"])
df_sessions.describe(datetime_is_numeric=True)
# Out:
#             session     Connector              starttime_parking  \
# count  1.000000e+04  10000.000000                          10000
# mean   3.452817e+06      1.360300  2019-07-11 12:25:16.866000128
# min    3.261657e+06      1.000000            2019-01-01 00:30:00
# 25%    3.360979e+06      1.000000            2019-04-04 12:43:45
# 50%    3.452182e+06      1.000000            2019-07-10 08:21:00
# 75%    3.547667e+06      2.000000            2019-10-22 06:54:00
# max    3.634120e+06      2.000000            2019-12-31 21:22:00
# std    1.076139e+05      0.480111                            NaN
#
#                      endtime_parking  connected_time_float  \
# count                          10000          10000.000000
# mean   2019-07-11 18:14:39.090000128              5.822735
# min              2019-01-01 08:24:00              0.020000
# 25%              2019-04-04 16:33:00              1.510000
# 50%              2019-07-10 13:31:30              3.380000
# 75%              2019-10-22 13:03:00              8.410000
# max              2020-01-01 16:00:00            161.170000
# std                              NaN              7.096361
#
#        charged_time_float  total_energy     max_power    start_hour  \
# count        10000.000000  10000.000000  10000.000000  10000.000000
# mean             2.878022     13.635216      5.589366     12.412600
# min              0.020000      0.100000      0.167000      0.000000
# 25%              1.250000      4.530000      3.398000      9.000000
# 50%              2.240000      7.830000      3.640000     12.000000
# 75%              3.500000     18.262500      7.277750     16.000000
# max             25.670000     93.929000     22.500000     23.000000
# std              2.644282     14.282036      3.333663      4.532131
#
#              day_no  energy_supplied       soc_arr  charged_time  \
# count  10000.000000     10000.000000  10000.000000  10000.000000
# mean     190.979600        28.608123      0.612398      3.355300
# min        0.000000         0.215600      0.000000      1.000000
# 25%       93.000000        13.475000      0.498375      2.000000
# 50%      190.000000        24.147200      0.668160      3.000000
# 75%      294.000000        37.730000      0.801562      4.000000
# max      364.000000        77.600000      0.967305     26.000000
# std      110.531348        20.586961      0.257337      2.650125
#
#        connected_time         ts_arr         ts_dep        ts_soj  \
# count    10000.000000   10000.000000   10000.000000  10000.000000
# mean         6.328300  171155.923000  171162.251300      6.328300
# min          1.000000  166560.000000  166568.000000      1.000000
# 25%          2.000000  168804.000000  168808.750000      2.000000
# 50%          4.000000  171128.000000  171133.500000      4.000000
# 75%          9.000000  173622.250000  173629.000000      9.000000
# max        162.000000  175317.000000  175336.000000    162.000000
# std          7.093627    2652.843492    2653.132903      7.093627
#
#              laxity   depart_hour            xi
# count  1.000000e+04  10000.000000  1.000000e+04
# mean   3.674485e+00     18.740900  1.980143e+01
# min   -4.440892e-16      2.000000 -2.393152e-15
# 25%    5.300000e-01     13.000000  2.856117e+00
# 50%    9.600000e-01     16.000000  5.173344e+00
# 75%    4.801484e+00     21.000000  2.587472e+01
# max    1.548015e+02    175.000000  8.342098e+02
# std    6.334915e+00      9.166023  3.413822e+01

# %%
# Note! This doesn't take into account the charging efficiency
(config.FINAL_SOC - df_sessions.soc_arr).sum() * config.B * 0.40
# Out:
# 114432.49312

# %%
df_sessions.energy_supplied.sum() * 0.40
# Out:
# 114432.49312
